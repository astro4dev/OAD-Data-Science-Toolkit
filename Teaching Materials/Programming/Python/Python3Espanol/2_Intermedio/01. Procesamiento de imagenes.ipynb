# %% [markdown]
# # Procesamiento de imagenes con matplotlib

# %% [markdown]
# Una imagen digital es simplemente un arreglo de datos (similar a una matriz), donde cada elemento corresponde a la informacion de cada pixel.
#
#
#    | |0|1|2|3|4|
#    |---|-----|----------|-- |-- |-- |
#    |**0**| 10 | 15 |  6 |  7 |  8 |
#    |**1**|  1 | 4  | 12 |  6 | 10 |
#    |**2**|  0 | 11 | 25 | 20 | 10 |
#    |**3**|  9 |  7 |  4 | 21 |  7 |
#    |**4**|  5 | 10 |  5 |  0 | 12 |

# %% [markdown]
# <img src="img/anim.gif">
#
# [Credito](https://medium.com/@ageitgey/machine-learning-is-fun-part-3-deep-learning-and-convolutional-neural-networks-f40359318721)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
imagen=plt.imread("img/caracol.jpg")

# %%
imagen
# Out:
# array([[[209, 187, 112],
#         [206, 184, 109],
#         [210, 188, 113],
#         ...,
#         [210, 187, 111],
#         [209, 183, 108],
#         [205, 179, 104]],
#
#        [[207, 185, 110],
#         [208, 186, 111],
#         [212, 190, 115],
#         ...,
#         [213, 187, 112],
#         [214, 188, 113],
#         [213, 187, 112]],
#
#        [[207, 185, 110],
#         [211, 189, 114],
#         [212, 190, 115],
#         ...,
#         [210, 184, 107],
#         [211, 185, 108],
#         [212, 185, 108]],
#
#        ...,
#        [[212, 177,  83],
#         [214, 179,  85],
#         [216, 181,  87],
#         ...,
#         [189, 130,  40],
#         [185, 126,  32],
#         [182, 124,  25]],
#
#        [[215, 180,  88],
#         [218, 183,  89],
#         [218, 183,  89],
#         ...,
#         [195, 133,  46],
#         [181, 120,  27],
#         [174, 114,  16]],
#
#        [[216, 181,  89],
#         [220, 185,  93],
#         [218, 183,  89],
#         ...,
#         [173, 111,  24],
#         [162, 101,   8],
#         [160, 100,   2]]], dtype=uint8)

# %%
plt.imshow(imagen)

# %%
plt.figure(figsize=(10,10))
plt.imshow(imagen)

# %%
plt.figure(figsize=(10,10))
plt.imshow(255-imagen)

# %%
plt.figure(figsize=(10,10))
plt.imshow(imagen[:,:,0],cmap="Greys")

# %%
plt.figure(figsize=(10,10))
plt.imshow(255-imagen[:,:,0],cmap="Greys")

# %%
imagen.shape
# Out:
# (910, 512, 3)

# %%
imagen.size
# Out:
# 1397760

# %%
imagen.min()
# Out:
# 0

# %%
imagen.max()
# Out:
# 255

# %% [markdown]
# ### Ejercicio:
#
# Muestra por aparte cómo se ve cada canal de R, G, y B usando un `cmap` acorde con el color del canal.

# %% [markdown]
# <img src="img/colormaps_reference_01.png">
# <img src="img/colormaps_reference_02.png">
# <img src="img/colormaps_reference_05.png">
# <img src="img/colormaps_reference_00.png">

# %% [markdown]
# ## Glitch
#
# <img src="img/glitch.jpg">
#
# Hay muchas maneras de glitchear digitalmente una imagen:

# %%
imagen**2
# Out:
# array([[[161, 153,   0],
#         [196,  64, 105],
#         [ 68,  16, 225],
#         ...,
#         [ 68, 153,  33],
#         [161, 209, 144],
#         [ 41,  41,  64]],
#
#        [[ 97, 177,  68],
#         [  0,  36,  33],
#         [144,   4, 169],
#         ...,
#         [ 57, 153,   0],
#         [228,  16, 225],
#         [ 57, 153,   0]],
#
#        [[ 97, 177,  68],
#         [233, 137, 196],
#         [144,   4, 169],
#         ...,
#         [ 68,  64, 185],
#         [233, 177, 144],
#         [144, 177, 144]],
#
#        ...,
#        [[144,  97, 233],
#         [228,  41,  57],
#         [ 64, 249, 145],
#         ...,
#         [137,   4,  64],
#         [177,   4,   0],
#         [100,  16, 113]],
#
#        [[145, 144,  64],
#         [164, 209, 241],
#         [164, 209, 241],
#         ...,
#         [137,  25,  68],
#         [249,  64, 217],
#         [ 68, 196,   0]],
#
#        [[ 64, 249, 241],
#         [ 16, 177, 201],
#         [164, 209, 241],
#         ...,
#         [233,  33,  64],
#         [132, 217,  64],
#         [  0,  16,   4]]], dtype=uint8)

# %%
plt.figure(figsize=(10,10))
plt.imshow(imagen**2)

# %%
plt.imshow?
